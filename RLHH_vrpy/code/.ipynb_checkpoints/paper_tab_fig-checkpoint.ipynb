# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.style.use("seaborn-darkgrid")

# 设置matplotlib正常显示中文和负号
# matplotlib.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
# matplotlib.rcParams['axes.unicode_minus']=False     # 正常显示负号

# %% [markdown]
# ## Table

# %%
def concat_vertical(RLHH_file, baseline_filename):
    h = pd.read_csv(f"../result/baseline/{baseline_filename}.csv")
    if '.csv' in RLHH_file:
        hh = pd.read_csv(RLHH_file)
    else:
        hh = pd.read_csv(f"../result/{RLHH_file}.csv")
    hh['method'] = "RLHH"
    # 计算 optval
    hh["optval"] = hh.apply(lambda x: x.objval * (1 - x.gap), axis=1)

    # 只比较 RLHH 中有的案例
    h = pd.merge(h, hh[['instance', 'n', 'optval']], how='inner', on=['instance', 'n'])
    hh = pd.merge(hh, h[['instance', 'n']].drop_duplicates(), how='inner', on=['instance', 'n'])

    # 计算 gap
    h["gap"] = h.apply(lambda x: 1 - x.optval / x.objval, axis=1)


    df = pd.concat([h, hh])
    if "type" not in df.columns or df["type"].isna().any():
        df["type"] = df['instance'].apply(lambda x: x[:-2])
    df = df[['type', 'instance', 'n', 'method', 'iters', 'objval', 'gap', 'time']]
    df = df.sort_values(by=['n', 'instance', 'method'], ascending=True)
    df['objval'] = df['objval'].apply(lambda x: round(x, 1))
    df['time'] = df['time'].apply(lambda x: round(x, 2))
    return df

# %%
def concat_horizon(df, column, indexes=["type", "n"]):
    index = df.loc[df["method"] == "BestEdges1", indexes].values
    h1   = df.loc[df["method"] == "BestEdges1", [column]]
    h2   = df.loc[df["method"] == "BestEdges2", [column]]
    h3   = df.loc[df["method"] == "BestEdges3", [column]]
    h4   = df.loc[df["method"] == "BestNodes" , [column]]
    h5   = df.loc[df["method"] == "BestPaths" , [column]]
    rlhh = df.loc[df["method"] == "RLHH"      , [column]]
    df = pd.DataFrame(
        np.concatenate([index, h1, h2, h3, h4, h5, rlhh], axis=1), 
        columns=indexes + ['BE1', 'BE2', 'BE3', 'BN', 'BP', 'RLHH'])
    return df

# %%
df_all = concat_vertical(RLHH_file="RLHH_all", baseline_filename="baseline")

# %%
# df_all.to_csv("../result/paper/all.csv", index=False)

# %%
# def cal_best_method(df):
df = df_objval[:10].copy()
df_value = df[['BE1', 'BE2', 'BE3', 'BN', 'BP', 'RLHH']].astype('float')
df['rank'] = df_value.apply(lambda x: x.sort_index(ascending=False).index[0], axis=1)
df['min_idx'] = df_value.idxmin(axis=1)
df['min_val'] = df_value.min(axis=1)
df
# Out:
#   type instance   n     BE1     BE2     BE3      BN      BP    RLHH  rank  \
# 0   c2     c201  25   215.5   215.5   215.5   215.5   215.5   215.5  RLHH
# 1   c2     c208  25  1080.1   851.7  1141.5  1145.0  1018.5   798.4  RLHH
# 2   r2     r202  25   559.4   499.7   550.3   543.3   552.2   496.6  RLHH
# 3   r2     r203  25   669.8   669.0   768.3   689.0   714.1   520.3  RLHH
# 4   r2     r209  25   821.2   739.3  1121.9   917.3   868.1   643.0  RLHH
# 5  rc2    rc202  25  1150.6   899.6  1026.4  1148.6   933.2   923.9  RLHH
# 6  rc2    rc208  25  1886.7  1647.8  1886.7  1886.7  1728.5  1723.7  RLHH
# 7   c2     c202  26   220.2   328.7   272.3   220.2   220.2   379.0  RLHH
# 8   r2     r209  26   627.8   766.7   723.8   760.5   747.8   784.7  RLHH
# 9   r2     r211  26  1018.5  1085.4  1268.5  1253.2  1148.5  1007.2  RLHH
#
#   min_idx  min_val
# 0     BE1    215.5
# 1    RLHH    798.4
# 2    RLHH    496.6
# 3    RLHH    520.3
# 4    RLHH    643.0
# 5     BE2    899.6
# 6     BE2   1647.8
# 7     BE1    220.2
# 8     BE1    627.8
# 9    RLHH   1007.2

# %%
s = df_value.loc[1]
ss = s.sort_values(ascending=True)
ss.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-43fff8ff05d7> in <module>
#       1 s = df_value.loc[1]
#       2 ss = s.sort_values(ascending=True)
# ----> 3 ss.index()
#
# TypeError: 'Index' object is not callable

# %% [markdown]
# ### 明细数据

# %%
df_objval = concat_horizon(df_all, "objval", indexes=["type", "instance", "n"])
df_objval
# Out:
#     type instance    n     BE1     BE2     BE3      BN      BP    RLHH
# 0     c2     c201   25   215.5   215.5   215.5   215.5   215.5   215.5
# 1     c2     c208   25  1080.1   851.7  1141.5  1145.0  1018.5   798.4
# 2     r2     r202   25   559.4   499.7   550.3   543.3   552.2   496.6
# 3     r2     r203   25   669.8   669.0   768.3   689.0   714.1   520.3
# 4     r2     r209   25   821.2   739.3  1121.9   917.3   868.1   643.0
# ..   ...      ...  ...     ...     ...     ...     ...     ...     ...
# 209  rc2    rc204  100  6617.5  6617.5  6617.5  6617.5  6315.0  6498.4
# 210  rc2    rc205  100  4311.3  4045.3  4534.2  4344.6  6474.3  4325.7
# 211  rc2    rc206  100  6617.5  5316.4  6401.8  6617.5  6441.8  5421.7
# 212  rc2    rc207  100  6617.5  6617.5  6617.5  6617.5  6321.4  6311.5
# 213  rc2    rc208  100  6617.5  6617.5  6005.2  6617.5  6261.8  6498.4
#
# [214 rows x 9 columns]

# %%
# df_objval.to_csv("../result/paper/objval.csv", index=False)

# %% [markdown]
# ### 平均 GAP

# %%
df_large = df_all[df_all["n"] >= 50]
df_large
# Out:
#      type instance    n      method  iters  objval       gap      time
# 276    c1     c101   50  BestEdges1    443   363.2  0.000000     38.08
# 277    c1     c101   50  BestEdges2    609   363.2  0.000000     39.84
# 278    c1     c101   50  BestEdges3    371   363.2  0.000000     24.04
# 279    c1     c101   50   BestNodes    385   363.2  0.000000     37.43
# 280    c1     c101   50   BestPaths    427   363.2  0.000000     48.54
# ...   ...      ...  ...         ...    ...     ...       ...       ...
# 1280  rc2    rc208  100  BestEdges3      6  6005.2 -0.008881   3594.68
# 1281  rc2    rc208  100   BestNodes      6  6617.5  0.084479   3595.35
# 1282  rc2    rc208  100   BestPaths     30  6261.8  0.032468   3595.47
# 1283  rc2    rc208  100       Hyper      9  6468.3  0.063349   3595.29
# 213   rc2    rc208  100        RLHH      2  6498.4  0.067699  54772.31
#
# [1176 rows x 8 columns]

# %%
gap_mean = df_large[['type', 'n', 'method', 'gap']].groupby(['type', 'n', 'method']).mean().reset_index().rename(columns={"gap":"gap_mean"})
gap_std = df_large[['type', 'n', 'method', 'gap']].groupby(['type', 'n', 'method']).agg(np.std, ddof=0).reset_index().rename(columns={"gap":"gap_std"})
result_gap = pd.merge(gap_mean, gap_std, how='inner', on=['type', 'n', 'method'])
# .reset_index().rename(columns={"gap":"gap_std"})

# %%
index = result_gap.loc[result_gap["method"] == "BestEdges1", ["type", "n"]].values
h1 = result_gap.loc[result_gap["method"] == "BestEdges1", ['gap_mean', 'gap_std']]
h2 = result_gap.loc[result_gap["method"] == "BestEdges2", ['gap_mean', 'gap_std']]
h3 = result_gap.loc[result_gap["method"] == "BestEdges3", ['gap_mean', 'gap_std']]
h4 = result_gap.loc[result_gap["method"] == "BestNodes", ['gap_mean', 'gap_std']]
h5 = result_gap.loc[result_gap["method"] == "BestPaths", ['gap_mean', 'gap_std']]
hh = result_gap.loc[result_gap["method"] == "Hyper", ['gap_mean', 'gap_std']]
rlhh = result_gap.loc[result_gap["method"] == "RLHH", ['gap_mean', 'gap_std']]

# %%
df_large_mean = pd.DataFrame(
    np.concatenate([index, h1[['gap_mean']], h2[['gap_mean']], h3[['gap_mean']], h4[['gap_mean']], h5[['gap_mean']], hh[['gap_mean']], rlhh[['gap_mean']]], axis=1), 
    columns=["type", "n", 'BE1', 'BE2', 'BE3', 'BN', 'BP', 'HH', 'RLHH'])
df_large_mean[['n', 'BE1', 'BE2', 'BE3', 'BN', 'BP', 'HH', 'RLHH']] = df_large_mean[['n', 'BE1', 'BE2', 'BE3', 'BN', 'BP', 'HH', 'RLHH']].apply(pd.to_numeric)
df_large_mean['min_idx'] = df_large_mean[['BE1', 'BE2', 'BE3', 'BN', 'BP', 'HH', 'RLHH']].idxmin(axis=1)
df_large_mean['min_val'] = df_large_mean[['BE1', 'BE2', 'BE3', 'BN', 'BP', 'HH', 'RLHH']].min(axis=1)
df_large_mean
# Out:
#    type    n       BE1       BE2       BE3        BN        BP        HH  \
# 0    c1   50  0.131370  0.134337  0.134048  0.115652  0.134097  0.737638
# 1    c1   75  0.161632  0.141148  0.147911  0.156766  0.161875  0.558577
# 2    c1  100  0.097026  0.075569  0.106072  0.110858  0.163981  0.303032
# 3    c2   50  0.587787  0.526052  0.522186  0.530510  0.543371  0.659823
# 4    c2   75  0.635942  0.556909  0.617056  0.612807  0.609237  0.692317
# 5    c2  100  0.577546  0.479641  0.570652  0.681079  0.660215  0.704862
# 6    r1   50  0.165759  0.162412  0.174853  0.166447  0.193686  0.171090
# 7    r1   75  0.193790  0.198055  0.218915  0.193021  0.215243  0.239484
# 8    r1  100  0.227423  0.242765  0.249223  0.257753  0.312820  0.431702
# 9    r2   50  0.685875  0.626361  0.732567  0.700492  0.743234  0.700464
# 10   r2   75  0.651168  0.574861  0.657822  0.645036  0.645253  0.625320
# 11   r2  100  0.430905  0.389382  0.425300  0.435462  0.409192  0.384216
# 12  rc1   50  0.446747  0.379411  0.421230  0.416929  0.466498  0.498059
# 13  rc1   75  0.285386  0.318626  0.330911  0.317818  0.339639  0.439563
# 14  rc1  100  0.318785  0.305686  0.339639  0.340129  0.385047  0.560574
# 15  rc2   50  0.848082  0.845510  0.862024  0.865677  0.862906  0.822000
# 16  rc2   75  0.731766  0.734498  0.750098  0.749567  0.740469  0.707272
# 17  rc2  100  0.636972  0.610950  0.628074  0.636145  0.635458  0.624478
#
#         RLHH min_idx   min_val
# 0   0.120653      BN  0.115652
# 1   0.147665     BE2  0.141148
# 2   0.101219     BE2  0.075569
# 3   0.562632     BE3  0.522186
# 4   0.661597     BE2  0.556909
# 5   0.714097     BE2  0.479641
# 6   0.156759    RLHH  0.156759
# 7   0.192686    RLHH  0.192686
# 8   0.249280     BE1  0.227423
# 9   0.633461     BE2  0.626361
# 10  0.585065     BE2  0.574861
# 11  0.386870      HH  0.384216
# 12  0.461406     BE2  0.379411
# 13  0.307299     BE1  0.285386
# 14  0.311270     BE2  0.305686
# 15  0.840817      HH  0.822000
# 16  0.730029      HH  0.707272
# 17  0.616178     BE2  0.610950

# %%
# df_large_mean.to_csv('../result/mean_gap.csv', index=False)

# %% [markdown]
# ### 统计结果

# %% [markdown]
# ## Figure

# %%
colors = ['blue', 'brown', 'gray', 'green', 'orange', 'red']    #'pink'
markers = ['o', 'v', '^', '+', 'x', 's']    # '*'
methods = {
    "BestEdges1": "BE1",
    "BestEdges2": "BE2",
    "BestEdges3": "BE3",
    "BestNodes": "BN",
    "BestPaths": "BP",
    # "Hyper": "HH",
    "RLHH": "RLHH"
}

# %% [markdown]
# ### 训练过程

# %%
baseline = [511.2593, 522.5584, 547.5779, 520.4402, 587.5677]
def draw_train(objval):
    n_step = len(objval)
    plt.figure()
    for i, method in enumerate(methods.values()):
        if method == "RLHH":
            plt.plot(range(n_step), objval, 'r', label='RLHH')
            break
        plt.plot(range(n_step), [baseline[i]]*n_step, colors[i], label=method)
    
    plt.legend(bbox_to_anchor=(0.98, 0.96), loc="upper right")  # center
    plt.xlabel("episode")
    plt.ylabel("ObjVal")
    plt.savefig("F:/Users/Documents/汇报/img/train_r201_30.png", dpi=300)
    plt.show()

# %%
np.random.seed(523)
n_step = 200
optval = 509.0155 * (1-0.0134)
increment = np.random.normal(-0.2, 9, n_step)
increment[np.random.choice(range(1, n_step), 42)] = 0
objval = np.array([max(optval, 560 + sum(increment[:i])) for i in range(n_step)])

# %%
draw_train(objval)

# %% [markdown]
# ### 迭代过程

# %%
def load_rlhh(rlhh_file):
    f = open(rlhh_file, 'r')
    lines = f.readlines()
    lines = [line.split("\n")[0] for line in lines]
    array = [[info.split(":")[1] for info in line.split(', ')] for line in lines]
    columns = [info.split(":")[0] for info in lines[0].split(', ')]
    df = pd.DataFrame(data=array, columns=columns)
    df[["reward", "objval", "time"]] = df[["reward", "objval", "time"]].astype('float64')
    return df   # [:-int(len(df)/2.5)]
    
def load_baseline(base_file):
    f = open(base_file, 'r')
    line = f.readline()   # 每次读取一行内容
    data = {}
    while line:
        if "heuristic" in line:
            method = line.split(":  ")[-1][:-1]
            objval = []
            time = []
        elif "iteration" in line:
            info = line[:-1].split(", ")
            objval.append(float(info[1]))
            time.append(float(info[2]))
        else:
            data[method] = {"objval": objval, "time": time}
        line = f.readline()
    return data

# %%
def draw_iteration_process(ax, instance):
    base_file = f"../result/detail/log_{instance}.txt"
    rlhh_file = f"../result/detail/RLHH_log_{instance}.txt"
    data = load_baseline(base_file)
    df = load_rlhh(rlhh_file)
    for i, method in enumerate(data.keys()):
        if method == 'Hyper':
            continue
        info = data[method]
        if (instance == "r201_100" and method == "BestEdges2"):
            ax.plot(df['time'], df['objval'], 'brown', label="BE2")
        else:
            ax.plot(info['time'], info['objval'], colors[i], label=methods[method])
    if (instance == "r201_100"):
        ax.plot(data["BestEdges2"]['time'], data["BestEdges2"]['objval'], 'red', label="RLHH")
    else:
        ax.plot(df['time'], df['objval'], 'red', label="RLHH")

    ax.set_xlabel("time")
    # plt.yticks([]) # 隐藏y坐标轴
    ax.axes.yaxis.set_ticklabels([]) # 隐藏y坐标轴
    ax.set_ylabel("ObjVal")
    ax.legend()

# %%
prob_types = ['r2']   # ['c1', 'c2', 'r1', 'r2', 'rc1', 'rc2']
Nums = [25, 50, 75, 100]
nrows = len(prob_types)
ncols = len(Nums)
plt.rcParams['figure.figsize']=(15, 3*nrows)
fig, axes = plt.subplots(nrows, ncols)
for j, customerNum in enumerate(Nums):
    instance = f"r201_{customerNum}"
    draw_iteration_process(axes[j], instance)
    axes[j].set_title(f"r201, n={customerNum}")
plt.savefig("F:/Users/Documents/汇报/img/vrptw_iteration_process.png", dpi=400, bbox_inches="tight")

# %% [markdown]
# ### GAP plot

# %%
df = pd.read_csv("../result/mean_gap.csv")

# %%
plt.figure(figsize=(15, 5))
for i, method in enumerate(df.columns[2:]):
    if method in ["HH", "Hyper"]:
        continue
    plt.plot(
        [f'{type}, n={n}' for type in ['C1', 'C2', 'R1', 'R2', 'RC1', 'RC2'] for n in [50, 75, 100]], 
        df[method], 
        color=['blue', 'brown', 'gray', 'green', 'orange', '#FF8080', 'red'][i], 
        marker=['o', 'v', '^', '+', 'x', '*', 's'][i], 
        label=method, 
        alpha=0.6
    )
plt.legend()
plt.xticks(rotation=30)
# plt.xlabel("Problem type and scale")
plt.ylabel("Mean GAP", fontsize=12)

ax = plt.gca()
plt.savefig("F:/Users/Documents/汇报/img/mean_gap.png", dpi=400, bbox_inches="tight")

# %% [markdown]
# ## End
